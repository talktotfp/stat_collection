# %%
import requests
import bs4
import numpy as np
import pandas as pd
import datetime
import pymysql
import cx_Oracle

#oracle_con = cx_Oracle.connect('tylerp/tp323ean@ukudbsh1/ukm25d')
#oracle_query = "select * from PGAME_STAT_BASE where PLAYER_ID < 2000 and PLAYER_ID >1000"
#oracle_df = pd.read_sql_query(oracle_query,oracle_con)
#print(oracle_df)
#print (oracle_df.corr('pearson'))
#oracle_con.close()


#connect to MySQL database
conn = cx_Oracle.connect('tylerp/tp323ean@ukudbsh1/ukm25d')
#create connection cursor
cur = conn.cursor()


#get text from HTML document as response
response = requests.get('http://www.rotowire.com/daily/NBA/optimizer.php?site=FanDuel')

#setup BeaufifulSoup 
soup = bs4.BeautifulSoup(response.text,"lxml")


#find table in HTML by looking for 'tr' table row objects
table_body = soup.find_all('tr')

#build blank lists to be filled in
l_names = []
l_tm = []
l_opp = []
l_pos = []
l_sal = []
l_mins = []
l_pts = []
date = datetime.datetime.today().strftime("%m_%d_%Y")

#loop through all rows in HTML (table_body find all 'td')
for rows in table_body[2:]:
    col = rows.find_all('td')
    
    #find name and replace GTD and special characters
    nm = col[1].text.strip().replace("\nGTD", "").lower().replace(".","")
    tm = col[2].text.strip()
    opp = col[3].text.strip()
    pos = col[4].text.strip()
    
    #find mins, salary, and points and convert to floats
    mins = float(col[7].text.strip().replace(",", ""))
    sal = float(col[8].attrs.get("data-salary").replace(",", ""))
    pts = float(col[9].attrs.get("data-points").replace(",", ""))
    
    #append each of the columns to their respective lists
    l_names.append(nm)
    l_tm.append(tm)
    l_opp.append(opp)
    l_pos.append(pos)
    l_sal.append(sal)
    l_mins.append(mins)
    l_pts.append(pts)

#build dataframe from lists
pd_data = pd.DataFrame(
    {'name': l_names,
     'team': l_tm,
     'pos': l_pos,
     'opp': l_opp,
     'sal': l_sal,
     'mins': l_mins,
     'pts': l_pts,
     'date' : date
    })

print(pd_data)
#old system to CSV
pd_data.to_csv(date + '_fd_lineup.csv')

#iterate through dataframe to insert new records to lineup_fd table
for index, row in pd_data.iterrows():
    insert_query = '''insert into LINEUP_FD (NAME, GDATE,RW_MIN, RW_PTS, SAL, OPP, POS, TM) 
               values (lower(:1),TO_DATE(:2,'mm_dd_yyyy'),:3,:4,:5,:6,:7,:8)'''

    val1 =str(pd_data.iloc[index]['name'])
    val2 =str(pd_data.iloc[index]['date'])
    val3 = str( pd_data.iloc[index]['mins'])
    val4 =str(pd_data.iloc[index]['pts'])
    val5 = str( pd_data.iloc[index]['sal'])
    val6 =str(pd_data.iloc[index]['opp'])
    val7 =str(pd_data.iloc[index]['pos'])
    val8 = str( pd_data.iloc[index]['team'])

# 29   12_15_2016  29.0            tim frazier   IND  PG  25.6   5600.0  NOP
# ..          ...   ...                    ...   ...  ..   ...      ...  ...
# 109  12_15_2016   8.0          georges niang   @NO  SF   5.8   3500.0  IND
# 110  12_15_2016   7.0          miles plumlee   CHI   C   5.7   3500.0  MIL
# 111  12_15_2016   5.0         tim quarterman  @DEN  PG   5.5   3500.0  POR
# 112  12_15_2016  13.0            jason terry   CHI  PG   5.3   3500.0  MIL
# 113  12_15_2016   6.0       anderson varejao   NYK   C   5.2   3500.0  GSW
# 114  12_15_2016  10.0          dragan bender   SAS  PF   4.9   3500.0  PHO
# 115  12_15_2016   8.0          sasha vujacic   @GS  SG   4.9   3500.0  NYK
# 116  12_15_2016   6.0           joseph young   @NO  SG   4.9   3700.0  IND
# 117  12_15_2016   8.0            jake layman  @DEN  PF   4.6   3500.0  POR
# 118  12_15_2016   7.0          maurice ndour   @GS  PF   4.5   3500.0  NYK
# 119  12_15_2016   8.0        reggie williams   IND  SG   4.2   3500.0  NOP
# 120  12_15_2016   6.0         shabazz napier  @DEN  PG   4.2   3500.0  POR
# 121  12_15_2016   5.0           james mcadoo   NYK  PF   4.1   3500.0  GSW
# 122  12_15_2016   7.0            paul zipser  @MIL  SF   4.1   3500.0  CHI
# 123  12_15_2016   8.0             alonzo gee   POR  SF   3.9   3500.0  DEN
# 124  12_15_2016   7.0              ron baker   @GS  PG   3.7   3500.0  NYK
# 125  12_15_2016   4.0           damian jones   NYK   C   3.3   3500.0  GSW
# 126  12_15_2016   5.0       marshall plumlee   @GS   C   3.3   3500.0  NYK
# 127  12_15_2016   6.0   nicolas laprovittola  @PHO  PG   3.1   3500.0  SAS
# 128  12_15_2016   4.0             thon maker   CHI  PF   3.1   3500.0  MIL
# 129  12_15_2016   6.0          malik beasley   POR  SG   3.0   3500.0  DEN
# 130  12_15_2016   5.0        pat connaughton  @DEN  SG   2.9   3500.0  POR
# 131  12_15_2016   3.0          cheick diallo   IND  PF   2.9   3600.0  NOP
# 132  12_15_2016   7.0          rashad vaughn   CHI  SG   2.8   3500.0  MIL
# 133  12_15_2016   5.0           john jenkins   SAS  SG   2.6   3500.0  PHO
# 134  12_15_2016   5.0              rj hunter  @MIL  SG   2.3   3500.0  CHI
# 135  12_15_2016   5.0            mike miller   POR  SF   2.2   3500.0  DEN
# 136  12_15_2016   3.0       rakeem christmas   @NO   C   2.1   3500.0  IND
# 137  12_15_2016   5.0            bryn forbes  @PHO  SG   1.6   3500.0  SAS
# 138  12_15_2016   3.0            steve novak   CHI  SF   0.8   3500.0  MIL
#
# [139 rows x 8 columns]
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# 12_15_2016
# done
