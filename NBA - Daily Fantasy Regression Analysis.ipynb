# %%
# import pymysql
import pandas as pd
import cx_Oracle
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
import statsmodels.api as sm
import logging

oracle_con = cx_Oracle.connect('tylerp/tp323ean@ukudbsh1/ukm25d')
oracle_cur = oracle_con.cursor()

oracle_query = "select GDATE, DFS, ADJ_MOD1_PROJ, DVP, DVP_RANK, DVP_PCT, LAST_GAME, HOME from MOD_RESULTS where DVP is NOT NULL order by GDATE "
oracle_df = pd.read_sql_query(oracle_query,oracle_con)

#print(oracle_df.corr(method='pearson'))  
y = oracle_df['DFS']
X = oracle_df[['ADJ_MOD1_PROJ','DVP','LAST_GAME','HOME']]

X = sm.add_constant(X)
model11 = sm.OLS(y, X).fit()


oracle_cur.close()        
oracle_con.close()

# %%
oracle_df.corr(method='pearson')
# Out:
#                     DFS  ADJ_MOD1_PROJ       DVP  DVP_RANK   DVP_PCT  \
# DFS            1.000000       0.780946  0.113327  0.025600  0.024138
# ADJ_MOD1_PROJ  0.780946       1.000000  0.096937  0.004202  0.002747
# DVP            0.113327       0.096937  1.000000  0.773717  0.766160
# DVP_RANK       0.025600       0.004202  0.773717  1.000000  0.997606
# DVP_PCT        0.024138       0.002747  0.766160  0.997606  1.000000
# LAST_GAME     -0.090057      -0.145282 -0.018810 -0.028956 -0.025815
# HOME          -0.089793      -0.042422 -0.034060 -0.039203 -0.037922
#
#                LAST_GAME      HOME
# DFS            -0.090057 -0.089793
# ADJ_MOD1_PROJ  -0.145282 -0.042422
# DVP            -0.018810 -0.034060
# DVP_RANK       -0.028956 -0.039203
# DVP_PCT        -0.025815 -0.037922
# LAST_GAME       1.000000 -0.074345
# HOME           -0.074345  1.000000

# %%
model11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DFS   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.613
# Method:                 Least Squares   F-statistic:                     331.5
# Date:                Thu, 22 Dec 2016   Prob (F-statistic):          1.88e-170
# Time:                        15:25:17   Log-Likelihood:                -2983.2
# No. Observations:                 836   AIC:                             5976.
# Df Residuals:                     831   BIC:                             6000.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# const            -4.4306      2.645     -1.675      0.094        -9.622     0.761
# ADJ_MOD1_PROJ     1.0018      0.028     35.541      0.000         0.946     1.057
# DVP               0.1059      0.063      1.684      0.093        -0.018     0.229
# LAST_GAME         0.0963      0.107      0.899      0.369        -0.114     0.306
# HOME             -1.4956      0.598     -2.500      0.013        -2.670    -0.322
# ==============================================================================
# Omnibus:                       12.521   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.023
# Skew:                           0.228   Prob(JB):                     0.000901
# Kurtosis:                       3.440   Cond. No.                         410.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
