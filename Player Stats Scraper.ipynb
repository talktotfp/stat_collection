# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Dec  9 15:10:20 2016

@author: tpauley
"""

import requests
import bs4
import numpy as np
import pandas as pd
import logging
from string import ascii_lowercase
import cx_Oracle
#import cx_Oracle as oracle
import progressbar
from time import sleep
bar = progressbar.ProgressBar(maxval=20, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
for i in xrange(20):
    bar.update(i+1)
    sleep(0.1)
bar.finish()
    



oracle_con = cx_Oracle.connect('tylerp/tp323ean@ukudbsh1/ukm25d')
oracle_cur = oracle_con.cursor()

#url_list = []
#for c in ascii_lowercase:
#    try:
#        crawler = requests.get('http://www.basketball-reference.com/players/'+str(c)+'/')
#        crawl_soup = bs4.BeautifulSoup(crawler.text,"lxml")
#
#        crawl_table = crawl_soup.find('table')
#
#        for row in crawl_table.find_all('tr')[0:]:
#            for row in row.find_all('strong')[0:]:
#                crawler_name = row.find('a', href=True)
#                crawler_url = 'http://www.basketball-reference.com/'+crawler_name['href'].replace('.html','')+'/gamelog/2017'
#                url_list.append(crawler_url)
#    except Exception as e:
#        logging.exception("message")

#get text from HTML document as response
response = requests.get('http://www.basketball-reference.com/players/j/jamesle01/gamelog/2017/')

#setup BeaufifulSoup 
soup = bs4.BeautifulSoup(response.text,"lxml")


# Create an object of the first object that is class=dataframe
table = soup.find('tbody')

name = soup.find("h1", {"itemprop":"name"}).string.replace("2016-17 Game Log","").strip()
l_g = []
l_name = []
l_gdate = []
l_age = []
l_team = []
l_opp = []
l_home = []
l_gs = []
l_mp = []
l_fgm = []
l_fga = []
l_fgp = []
l_tpm = []
l_tpa = []
l_tpp = []
l_ftm = []
l_fta = []
l_ftp = []
l_orb = []
l_drb = []
l_trb = []
l_ast = []
l_stl = []
l_blk = []
l_tov = []
l_pf = []
l_pts = []
l_gmsc = []



# Find all the <tr> tag pairs, skip the first one, then for each.
for row in table.find_all('tr')[0:]:
    try:
        # Create a variable of all the <td> tag pairs in each <tr> tag pair,
        col = row.find_all('td')

        # Create a variable of the string inside 1st <td> tag pair,
        c_g = col[0].string.strip()
        c_name = col[1].string.strip()
        c_gdate = col[1].string.strip()
        c_age = col[2].string.strip()
        c_team = col[3].string.strip()
        c_opp = col[5].string.strip()
        if col[4].text == '':
            c_home = '0'
        else:
            c_home = '1'
        #c_home = col[4].text
        c_gs = col[7].string.strip()
        c_mp = col[8].string.strip()
        c_fgm = col[9].string.strip()
        c_fga = col[10].string.strip()
        c_fgp = col[11].string.strip()
        c_tpm = col[12].string.strip()
        c_tpa = col[13].string.strip()
        c_tpp = col[14].string.strip()
        c_ftm = col[15].string.strip()
        c_fta = col[16].string.strip()
        c_ftp = col[17].string.strip()
        c_orb = col[18].string.strip()
        c_drb = col[19].string.strip()
        c_trb = col[20].string.strip()
        c_ast = col[21].string.strip()
        c_stl = col[22].string.strip()
        c_blk = col[23].string.strip()
        c_tov = col[24].string.strip()
        c_pf = col[25].string.strip()
        c_pts = col[26].string.strip()
        c_gmsc = col[27].string.strip()
        # and append it to first_name variable
        l_g.append(c_g)
        l_name.append(name)
        l_gdate.append(c_gdate)
        l_age.append(c_age)
        l_team.append(c_team)
        l_opp.append(c_opp)
        l_home.append(c_home)
        l_gs.append(c_gs)
        l_mp.append(c_mp)
        l_fgm.append(c_fgm)
        l_fga.append(c_fga)
        l_fgp.append(c_fgp)
        l_tpm.append(c_tpm)
        l_tpa.append(c_tpa)
        l_tpp.append(c_tpp)
        l_ftm.append(c_ftm)
        l_fta.append(c_fta)
        l_ftp.append(c_ftp)
        l_orb.append(c_orb)
        l_drb.append(c_drb)
        l_trb.append(c_trb)
        l_ast.append(c_ast)
        l_stl.append(c_stl)
        l_blk.append(c_blk)
        l_tov.append(c_tov)
        l_pf.append(c_pf)
        l_pts.append(c_pts)
        l_gmsc.append(c_gmsc)
        
    except Exception as e:
        logging.exception("message")
    
#build dataframe from lists
pd_data = pd.DataFrame(
    {'a1_l_name' : l_name,
    'a1_l_g' : l_g,
    'l_gdate' : l_gdate,
    'l_age' : l_age,
    'l_team' : l_team,
    'l_opp' : l_opp,
    'l_home' : l_home,
    'l_gs' : l_gs,
    'l_mp' : l_mp,
    'l_fgm' : l_fgm,
    'l_fga' : l_fga,
    'l_fgp' : l_fgp,
    'l_tpm' : l_tpm,
    'l_tpa' : l_tpa,
    'l_tpp' : l_tpp,
    'l_ftm' : l_ftm,
    'l_fta' : l_fta,
    'l_ftp' : l_ftp,
    'l_orb' : l_orb,
    'l_drb' : l_drb,
    'l_trb' : l_trb,
    'l_ast' : l_ast,
    'l_stl' : l_stl,
    'l_blk' : l_blk,
    'l_tov' : l_tov,
    'l_pf' : l_pf,
    'l_pts' : l_pts,
    'l_gmsc' : l_gmsc
    })
print(name + ' Done')
#print(url_list)


for index, row in pd_data.iterrows():
    insert_query = '''insert into PGAME_BUFFER (NAME, GDATE, PTS)
    values (:1,TO_DATE(:2,'yyyy-mm-dd'),TO_NUMBER(:3)'''
    
    val1 =' '.join(map(str, pd_data.iloc[index]['a1_l_name']))
    val2 =' '.join(map(str, pd_data.iloc[index]['l_gdate']))
    val3 =' '.join(map(str, pd_data.iloc[index]['l_pts']))
    oracle_cur.execute(insert_query,
                 (val1,val2,val3))
oracle_cur.close()
oracle_con.close()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-a362c1e58e07> in <module>()
#      15 #import cx_Oracle as oracle
#      16
# ---> 17 oracle_con = cx_Oracle.connect('tylerp/tp323ean@ukudbsh1/ukm25d')
#      18 oracle_cur = oracle_con.cursor()
#      19
#
# DatabaseError: ORA-12154: TNS:could not resolve the connect identifier specified
